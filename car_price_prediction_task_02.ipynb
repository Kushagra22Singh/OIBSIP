# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('CarPrice_Assignment.csv')

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# checking outliners

# %%
import seaborn as sns

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))

# Create six box plots on the subplots
sns.boxplot(x=df['car_ID'], ax=axes[0, 0])
sns.boxplot(x=df['symboling'], ax=axes[0, 1])
sns.boxplot(x=df['wheelbase'], ax=axes[0, 2])
sns.boxplot(x=df['carlength'], ax=axes[1, 0])
sns.boxplot(x=df['carwidth'], ax=axes[1, 1])
sns.boxplot(x=df['carheight'], ax=axes[1, 2])

# Set titles for each subplot
axes[0, 0].set_title('Box Plot for car_ID ')
axes[0, 1].set_title('Box Plot for symboling ')
axes[0, 2].set_title('Box Plot for wheelbase ')
axes[1, 0].set_title('Box Plot for carlength ')
axes[1, 1].set_title('Box Plot for carwidth ')
axes[1, 2].set_title('Box Plot for carheight ')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))

# Create six box plots on the subplots
sns.boxplot(x=df['curbweight'], ax=axes[0, 0])
sns.boxplot(x=df['enginesize'], ax=axes[0, 1])
sns.boxplot(x=df['boreratio'], ax=axes[0, 2])
sns.boxplot(x=df['stroke'], ax=axes[1, 0])
sns.boxplot(x=df['compressionratio'], ax=axes[1, 1])
sns.boxplot(x=df['horsepower'], ax=axes[1, 2])

# Set titles for each subplot
axes[0, 0].set_title('Box Plot for curbweight ')
axes[0, 1].set_title('Box Plot for enginesize ')
axes[0, 2].set_title('Box Plot for boreratio ')
axes[1, 0].set_title('Box Plot for stroke ')
axes[1, 1].set_title('Box Plot for compressionratio ')
axes[1, 2].set_title('Box Plot for horsepower ')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))

# Create box plots on the subplots
sns.boxplot(x=df['peakrpm'], ax=axes[0, 0])
sns.boxplot(x=df['citympg'], ax=axes[0, 1])
sns.boxplot(x=df['highwaympg'], ax=axes[1, 0])

# Set titles for each subplot
axes[0, 0].set_title('Box Plot for peakrpm')
axes[0, 1].set_title('Box Plot for citympg')
axes[1, 0].set_title('Box Plot for highwaympg')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# applying scaling to the outliner detected field and performing feature scaling

# %%
from sklearn import preprocessing

# %%
plt.hist(df['compressionratio'])
plt.title('Histogram before transformation')
plt.show()


scaler=preprocessing.StandardScaler()
df['compressionratio']=scaler.fit_transform(df['compressionratio'].values.reshape(-1,1))
plt.hist(df['compressionratio'])
plt.title('Histogram after transformation')
plt.show()

# %% [markdown]
# # Data Visualization

# %%
order = df['CarName'].value_counts().index.tolist()
plt.figure(figsize=(22,8))
sns.countplot(data=df, x='CarName', color='aqua', order=order)
plt.xticks(rotation=90)
plt.show()

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %% [markdown]
# applying labelencoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
le=LabelEncoder()

df['CarName']=le.fit_transform(df['CarName'])
df['fueltype']=le.fit_transform(df['fueltype'])
df['aspiration']=le.fit_transform(df['aspiration'])
df['doornumber']=le.fit_transform(df['doornumber'])
df['carbody']=le.fit_transform(df['carbody'])
df['drivewheel']=le.fit_transform(df['drivewheel'])
df['enginelocation']=le.fit_transform(df['enginelocation'])
df['enginetype']=le.fit_transform(df['enginetype'])
df['cylindernumber']=le.fit_transform(df['cylindernumber'])
df['fuelsystem']=le.fit_transform(df['fuelsystem'])

# %%
df.head()
# Out:
#    car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0       1          3        2         1           0           1        0
# 1       2          3        3         1           0           1        0
# 2       3          1        1         1           0           1        2
# 3       4          2        4         1           0           0        3
# 4       5          2        5         1           0           0        3
#
#    drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0           2               0       88.6  ...         130           5
# 1           2               0       88.6  ...         130           5
# 2           2               0       94.5  ...         152           5
# 3           1               0       99.8  ...         109           5
# 4           0               0       99.4  ...         136           5
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    int32
#  3   fueltype          205 non-null    int32
#  4   aspiration        205 non-null    int32
#  5   doornumber        205 non-null    int32
#  6   carbody           205 non-null    int32
#  7   drivewheel        205 non-null    int32
#  8   enginelocation    205 non-null    int32
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    int32
#  15  cylindernumber    205 non-null    int32
# ...

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
columns=['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
       'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
       'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
       'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
       'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg']
plt.figure(figsize=(18,12))
for i in range(25):
    plt.subplot(5, 5, i + 1) 
    sns.scatterplot(data=df, x=columns[i], y='price', color='salmon')
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.heatmap(df.corr() , annot=True , cmap='ocean')
# Out:
# <AxesSubplot: >

# %% [markdown]
# # applying PCA(principle component analysis) to reduce the dimensionality

# %%
X=df.drop('price',axis='columns')

# %%
y=df.price

# %%
from sklearn.decomposition import PCA

pca = PCA(0.90)
X_pca = pca.fit_transform(X)
X_pca.shape
# Out:
# (205, 2)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.63173859, 0.35631203])

# %% [markdown]
# splitting the data into train and test data

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
y_encoded
# Out:
# array([118, 137, 137, 123, 148, 128, 150, 159, 169, 151, 136, 145, 163,
#        164, 170, 174, 187, 184,   1,  11,  17,   7,  13,  49,  10,  20,
#         41,  63,  67, 114,  14,  25,   5,  16,  32,  34,  34,  47,  70,
#         65,  89, 113,  90,  22,  66,  66,  96, 177, 182, 183,   2,   8,
#         23,  21,  37,  95, 104, 120, 131,  65,  61,  91,  88,  93,  98,
#        154, 155, 171, 173, 172, 176, 180, 181, 186, 188, 138,   4,   9,
#         19,  42,  81,  62, 110, 126, 125,  28,  55,  73,  73,   6,  30,
#         18,  24,  36,  35,  46,  39,  52,  58,  69,  78, 119, 124, 119,
#        147, 162, 156, 106, 115, 109, 122, 130, 144, 142, 146, 141, 152,
#        153,   7,  49,  10,  20,  41,  67, 111, 166, 178, 179, 185, 175,
#         74,  80, 105, 107, 127, 129, 153, 158,   0,  29,  40,  31,  44,
#         82,  71, 100,  38,  87,  53, 103,   3,  12,  15,  26,  48,  64,
#         27,  33,  48,  45,  43,  59,  72,  54,  57,  75,  77,  60,  79,
# ...

# %% [markdown]
# # Model : Multivariate Linear Regression

# %%
from sklearn.model_selection import train_test_split
X_train_pca, X_test_pca, y_train, y_test = train_test_split(X_pca, y_encoded, test_size=0.2, random_state=30)

# %%
#Hyper-papameter tuning using gridsearch cv
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

model_LR = LinearRegression()
param_grid = {
    'fit_intercept': [True, False]}

grid_search = GridSearchCV(model_LR, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1, verbose=2)

grid_search.fit(X_train_pca, y_train)

print("Best Parameters:", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Best Parameters: {'fit_intercept': True}

# %%
# Use the best model to make predictions
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test_pca)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 519.4784061597221
# R-squared: 0.7904685668599452

# %% [markdown]
# same model but used NN

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(2,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)  # Output layer for regression
])

model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train_pca, y_train, epochs=50, batch_size=32, validation_data=(X_test_pca, y_test))

# Evaluate the model
loss = model.evaluate(X_test_pca, y_test)
print(f"Mean Squared Error on Test Set: {loss:.4f}")
# Out:
# Epoch 1/50
# 6/6 [==============================] - 1s 43ms/step - loss: 12498.3486 - val_loss: 9917.6553
# Epoch 2/50
# 6/6 [==============================] - 0s 13ms/step - loss: 7573.7158 - val_loss: 6023.5542
# Epoch 3/50
# 6/6 [==============================] - 0s 15ms/step - loss: 4574.1436 - val_loss: 3696.8743
# Epoch 4/50
# 6/6 [==============================] - 0s 13ms/step - loss: 3042.0925 - val_loss: 2581.5159
# Epoch 5/50
# 6/6 [==============================] - 0s 11ms/step - loss: 2503.5291 - val_loss: 2021.3260
# Epoch 6/50
# 6/6 [==============================] - 0s 12ms/step - loss: 2364.6628 - val_loss: 1782.9858
# Epoch 7/50
# 6/6 [==============================] - 0s 13ms/step - loss: 2371.6575 - val_loss: 1691.2626
# Epoch 8/50
# 6/6 [==============================] - 0s 12ms/step - loss: 2301.4646 - val_loss: 1665.2012
# Epoch 9/50
# 6/6 [==============================] - 0s 12ms/step - loss: 2248.9827 - val_loss: 1744.0728
# Epoch 10/50
# ...
